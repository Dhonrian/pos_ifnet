# %%
# %load_ext kedro.ipython
# Out:
# [04/05/25 22:44:25] INFO     Using                                                                  ]8;id=582335;file:///home/leo/.pyenv/versions/kobe/lib/python3.12/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=498628;file:///home/leo/.pyenv/versions/kobe/lib/python3.12/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/home/leo/.pyenv/versions/kobe/lib/python3.12/site-packages/kedro/fra
#                              mework/project/rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=417142;file:///home/leo/.pyenv/versions/kobe/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=786082;file:///home/leo/.pyenv/versions/kobe/lib/python3.12/site-packages/kedro/ipython/__init__.py#63\63]8;;\
# ...

# %%
import pandas as pd
df = catalog.load('predictions')
df
# Out:
# [04/05/25 22:55:46] INFO     Loading data from predictions (ParquetDataset)...                  ]8;id=754970;file:///home/leo/.pyenv/versions/kobe/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=674899;file:///home/leo/.pyenv/versions/kobe/lib/python3.12/site-packages/kedro/io/data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            lat       lon  minutes_remaining  period  playoffs  shot_distance  \
# 10     33.8063 -118.3638                  1       3         0             25
# 17     33.8183 -118.3868                  8       2         0             25
# 27     33.8583 -118.4528                  0       3         0             26
# 39     33.7723 -118.2968                  0       2         0             27
# 54     33.7973 -118.4108                  4       1         0             28
# ...

# %%
df.describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                lat          lon  minutes_remaining       period     playoffs  \
# count  6426.000000  6426.000000        6426.000000  6426.000000  6426.000000
# mean     33.849664  -118.263813           4.107688     2.704171     0.137255
# std       0.082910     0.157617           3.449276     1.149971     0.344143
# min      33.253300  -118.519800           0.000000     1.000000     0.000000
# 25%      33.805300  -118.421800           1.000000     2.000000     0.000000
# 50%      33.835300  -118.257800           4.000000     3.000000     0.000000
# 75%      33.877300  -118.115800           7.000000     4.000000     0.000000
# max      34.079300  -118.021800          11.000000     7.000000     1.000000
#
#        shot_distance  predictions
# count    6426.000000  6426.000000
# mean       25.581855     0.000156
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
#plot predictions with x and y being lat and lon
plt.scatter(df['lon'], df['lat'], c=df['predictions'], cmap='RdYlGn', s=10)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1000x600 with 1 Axes>
